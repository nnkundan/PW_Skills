# %%
# Change themes of Jupyter Notebook

# %% [markdown]
# ![Screenshot%202024-02-25%20at%2010.54.32%20PM.png](attachment:Screenshot%202024-02-25%20at%2010.54.32%20PM.png)

# %% [markdown]
# # Step 1 - Open terminal from above location
# # Step 2 - Write below command to change theme

# %%
# To Check list of themes
# jt -l


# To Change theme
# jt - t onedork

# %%
"""


(base) nnkundan@NNs-MacBook-Air ~ % jt -l
Available Themes:
   chesterish
   grade3
   gruvboxd
   gruvboxl
   monokai
   oceans16
   onedork
   solarizedd
   solarizedl
(base) nnkundan@NNs-MacBook-Air ~ % jt -t grade3
(base) nnkundan@NNs-MacBook-Air ~ % jt -t gruvboxd
(base) nnkundan@NNs-MacBook-Air ~ % jt -t gruvboxl
(base) nnkundan@NNs-MacBook-Air ~ % jt -t monokai
(base) nnkundan@NNs-MacBook-Air ~ % jt -t oceans16
(base) nnkundan@NNs-MacBook-Air ~ % jt -t solarizedd
(base) nnkundan@NNs-MacBook-Air ~ % jt -t solarizedl
(base) nnkundan@NNs-MacBook-Air ~ % jt -r
Reset css and font defaults in:
/Users/nnkundan/.jupyter/custom &
/Users/nnkundan/Library/Jupyter/nbextensions
(base) nnkundan@NNs-MacBook-Air ~ %



"""
# Out:
# '\n\n\n(base) nnkundan@NNs-MacBook-Air ~ % jt -l\nAvailable Themes:\n   chesterish\n   grade3\n   gruvboxd\n   gruvboxl\n   monokai\n   oceans16\n   onedork\n   solarizedd\n   solarizedl\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t grade3\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t gruvboxd\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t gruvboxl\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t monokai\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t oceans16\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t solarizedd\n(base) nnkundan@NNs-MacBook-Air ~ % jt -t solarizedl\n(base) nnkundan@NNs-MacBook-Air ~ % jt -r\nReset css and font defaults in:\n/Users/nnkundan/.jupyter/custom &\n/Users/nnkundan/Library/Jupyter/nbextensions\n(base) nnkundan@NNs-MacBook-Air ~ %\n\n\n\n'

# %%
# code to restore original theme
# jt -r

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               break               for                 not
# None                class               from                or
# True                continue            global              pass
# __peg_parser__      def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield

# %%
a=3
type(a)
# Out:
# int

# %%
c=1+1j
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 1.0

# %%
b="kundan"
type(b)
# Out:
# str

# %%
"""multi
line
comment

"""
# Out:
# 'multi\nline\ncomment\n\n'

# %%
# single

# %%
#intendation
if 2>5:
    print("False")
else:
    print("")

# %%
#standard input output
name = input('Enter your name: ') # by default it's string
# Out:
# Enter your name: N N Kundan

# %%
type(name)
# Out:
# str

# %%
Birth_year = input("Enter Your Birth Year: ")
# Out:
# Enter Your Birth Year: 1991

# %%
type(Birth_year)
# Out:
# str

# %%
#Type Casting
Birth_year=int(Birth_year)

# %%
type(Birth_year)
# Out:
# int

# %%
Birth_month = int(input("Enter Your Birth Year: "))
# Out:
# Enter Your Birth Year: 3

# %%
type(Birth_month)
# Out:
# int
